# %% [markdown]
# <a href="https://colab.research.google.com/github/Bellabaety1/Cimerwa-insurance-management-system/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install easynmt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.5 MB 31.3 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 48.3 MB/s
# ...
#      |████████████████████████████████| 68 kB 5.6 MB/s
# ...
#      |████████████████████████████████| 163 kB 48.0 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 31.6 MB/s
# ...
#   Using cached pybind11-2.10.1-py3-none-any.whl (216 kB)
# ...
#   Created wheel for easynmt: filename=EasyNMT-2.0.2-py3-none-any.whl size=19919 sha256=e289256adbf789649d3aaadea08f1ce743e2d1db50de44c4e6485ff75af8b585
#   Stored in directory: /root/.cache/pip/wheels/d1/57/06/53ca38645e14d4537a41e5a36da2026e10f54ae88240dd5190
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp37-cp37m-linux_x86_64.whl size=3161321 sha256=ddf78399c70066e3554779f2cbdcc5f9436c68a3ff4e9f43e9155a8c3a451110
#   Stored in directory: /root/.cache/pip/wheels/4e/ca/bf/b020d2be95f7641801a6597a29c8f4f19e38f9c02a345bab9b
# ...

# %%
pip install -U easynmt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from easynmt import EasyNMT

# %%
model = EasyNMT('opus-mt')

# %%
sentences=[
    'jesus is alive',
    'where were you last night',
     'am done with it',
     'am gratefull',
    
]

# %%
translation  = model.translate(sentences,target_lang='fr')
# Out:
# Downloading:   0%|          | 0.00/778k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/802k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/301M [00:00<?, ?B/s]

# %%
translation
# Out:
# ['Jésus est vivant',
#  'Où étais-tu hier soir?',
#  "J'en ai fini avec ça.",
#  'Je vous suis reconnaissant']

# %%
import json

# %%
with open('/content/ex.json', 'r+') as file_lang:
  content = file_lang.read()

# %%
languages_json = json.loads(content)

# %%
languages_json
# Out:
# [{'code': 'ab', 'name': 'Abkhaz'},
#  {'code': 'aa', 'name': 'Afar'},
#  {'code': 'af', 'name': 'Afrikaans'},
#  {'code': 'ak', 'name': 'Akan'},
#  {'code': 'sq', 'name': 'Albanian'},
#  {'code': 'am', 'name': 'Amharic'},
#  {'code': 'ar', 'name': 'Arabic'},
#  {'code': 'an', 'name': 'Aragonese'},
#  {'code': 'hy', 'name': 'Armenian'},
#  {'code': 'as', 'name': 'Assamese'},
#  {'code': 'av', 'name': 'Avaric'},
#  {'code': 'ae', 'name': 'Avestan'},
#  {'code': 'ay', 'name': 'Aymara'},
#  {'code': 'az', 'name': 'Azerbaijani'},
#  {'code': 'bm', 'name': 'Bambara'},
#  {'code': 'ba', 'name': 'Bashkir'},
#  {'code': 'eu', 'name': 'Basque'},
#  {'code': 'be', 'name': 'Belarusian'},
#  {'code': 'bn', 'name': 'Bengali; Bangla'},
#  {'code': 'bh', 'name': 'Bihari'},
#  {'code': 'bi', 'name': 'Bislama'},
#  {'code': 'bs', 'name': 'Bosnian'},
#  {'code': 'br', 'name': 'Breton'},
#  {'code': 'bg', 'name': 'Bulgarian'},
#  {'code': 'my', 'name': 'Burmese'},
# ...

# %%
languages_json[1]['code']
# Out:
# 'aa'

# %%
for language in languages_json:
  print(language['code'])
# Out:
# ab
# aa
# af
# ak
# sq
# am
# ar
# an
# hy
# as
# av
# ae
# ay
# az
# bm
# ba
# eu
# be
# bn
# bh
# bi
# bs
# br
# bg
# my
# ca
# ch
# ce
# ny
# zh
# cv
# kw
# co
# cr
# hr
# cs
# da
# dv
# nl
# dz
# en
# eo
# et
# ee
# fo
# fj
# fi
# fr
# ff
# gl
# ka
# de
# el
# gn
# gu
# ht
# ha
# he
# hz
# hi
# ho
# hu
# ia
# id
# ie
# ga
# ig
# ik
# io
# is
# it
# iu
# ja
# jv
# kl
# kn
# kr
# ks
# kk
# km
# ki
# rw
# ky
# kv
# kg
# ko
# ku
# kj
# la
# lb
# lg
# li
# ln
# lo
# lt
# lu
# lv
# gv
# mk
# mg
# ms
# ml
# mt
# mi
# mr
# mh
# mn
# na
# nv
# nb
# nd
# ne
# ng
# nn
# no
# ii
# nr
# oc
# oj
# cu
# om
# or
# os
# pa
# pi
# fa
# pl
# ps
# pt
# qu
# rm
# rn
# ro
# ru
# sa
# sc
# sd
# se
# sm
# sg
# sr
# gd
# sn
# si
# sk
# sl
# so
# st
# es
# su
# sw
# ss
# sv
# ta
# te
# tg
# th
# ti
# bo
# tk
# tl
# tn
# to
# tr
# ts
# tt
# tw
# ty
# ug
# uk
# ur
# uz
# ve
# vi
# vo
# wa
# cy
# wo
# fy
# xh
# yi
# yo
# za
# zu

# %%
for language in languages_json:
  print(language['name'])
# Out:
# Abkhaz
# Afar
# Afrikaans
# Akan
# Albanian
# Amharic
# Arabic
# Aragonese
# Armenian
# Assamese
# Avaric
# Avestan
# Aymara
# Azerbaijani
# Bambara
# Bashkir
# Basque
# Belarusian
# Bengali; Bangla
# Bihari
# Bislama
# Bosnian
# Breton
# Bulgarian
# Burmese
# Catalan; Valencian
# Chamorro
# Chechen
# Chichewa; Chewa; Nyanja
# Chinese
# Chuvash
# Cornish
# Corsican
# Cree
# Croatian
# Czech
# Danish
# Divehi; Dhivehi; Maldivian;
# Dutch
# Dzongkha
# English
# Esperanto
# Estonian
# Ewe
# Faroese
# Fijian
# Finnish
# French
# Fula; Fulah; Pulaar; Pular
# Galician
# Georgian
# German
# Greek, Modern
# GuaranÃ­
# Gujarati
# Haitian; Haitian Creole
# Hausa
# Hebrew (modern)
# Herero
# Hindi
# Hiri Motu
# Hungarian
# Interlingua
# Indonesian
# Interlingue
# Irish
# Igbo
# Inupiaq
# Ido
# Icelandic
# Italian
# Inuktitut
# Japanese
# Javanese
# Kalaallisut, Greenlandic
# Kannada
# Kanuri
# Kashmiri
# Kazakh
# Khmer
# Kikuyu, Gikuyu
# Kinyarwanda
# Kyrgyz
# Komi
# Kongo
# Korean
# Kurdish
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
rw_sentences = [
    'narakwanze pee',
    'kavunumuheto',
    'narakubuze ndigendera',
]

# %%
for language in languages_json[80:100]:
  code = language['code']
  try:
    #create new column with name as language code
    df[code] = model.translate(df['english'], source_lang='en', target_lang=code)
  except:
      pass

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df =
